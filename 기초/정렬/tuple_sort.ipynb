# %%
## (영어, 수학)
## 영어 내림차, 같으면 수학 내림차

scores = [
    (90, 80),
    (80, 90),
    (90, 70),  
    (80, 80),
]

scores.sort(key=lambda x: (-x[0], -x[1]))

for s in scores:
    print(s)
# Out:
# (90, 80)
# (90, 70)
# (80, 90)
# (80, 80)

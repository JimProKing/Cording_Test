# %%
# 정점 3개
N = 3
graph = [[] for _ in range(N+1)] ## 0번은 안쓸려고 함

# %%
# map(함수, 반복가능객체)
temp = [1,2,3,4,5,6,7,8,9]

b = list(map(lambda x: x*2, temp))

# %%
# 정점 수와 간선 수 입력
N,E = map(int, input().split())

# %%
## 나머지 분배법칙
print(26%3) ## 결과는 2

## (A+B)%C = (A%C + B%C)%C
print((20%3+6%3)%3) ## 결과는 2

## 뺄셈 분배법칙
## (A-B)%C = (A%C - B%C)%C
primt((20-6)%3) ## 결과는 2
print((20%3-6%3)%3) ## 결과는 2
# Out:
# 2
# 2
